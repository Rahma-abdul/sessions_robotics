# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 3]
def displayImage(img):
    plt.imshow(img, cmap='gray')
    plt.show()
    
img1= cv2.imread('./pics/img1.jpg',0)
img2= cv2.imread('./pics/img1.jpg',0)
plt.title("Orignal")
displayImage(img1)

plt.title("TO ZERO")
img1[img1<70] = 0
displayImage(img1)
plt.title("TO ZERO INV")
img2[img2>70] = 0
displayImage(img2)
